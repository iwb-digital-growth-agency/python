# %% [markdown]
# # Benodigde libraries importeren

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import pandas.api.types as ptypes

# %% [markdown]
# # Bestand inladen en data filteren

# %%
# excel bestand maxilia geimporteerd en kolommen gefilterd 

data = pd.read_excel(r'/Users/lisannepeeters/downloads/Kleine dataset.xlsx')
df = pd.DataFrame(data, columns = ['email','Orderdate','OrderID','TurnoverLead'])

df
# Out:
#                                        email  Orderdate  OrderID  TurnoverLead
# 0                          jw@a-m-service.de 2015-04-01    44409        494.00
# 1                 mieke.sanders@verscombi.nl 2015-04-01    48003        460.00
# 2                 mieke.sanders@verscombi.nl 2015-04-01    48003        460.00
# 3             beate.hardtke@dertouristik.com 2015-04-01    48957       2385.00
# 4                  follower4christ@gmail.com 2015-04-01    49063        970.00
# 5                  follower4christ@gmail.com 2015-04-01    49063        970.00
# 6                   info@druckhaus-kunger.de 2015-04-01    49118        266.75
# 7                    zeem0900@student.nhl.nl 2015-04-01    49227        108.50
# 8                   b.froehlich@maximare.com 2015-04-01    49337       1095.00
# 9     marco.vanruitenbeek@globalknowledge.nl 2015-04-01    49338        570.50
# 10                   jolandaenwildie@home.nl 2015-04-01    49342        199.50
# 11                      n.kissel@t-online.de 2015-04-01    49391        225.00
# 12                    marjan@talentsearch.nl 2015-04-01    49397       4994.00
# 13                    marjan@talentsearch.nl 2015-04-01    49397       4994.00
# 14              Sarah.gund@networker-gmbh.de 2015-04-01    49408        140.00
# 15                 annemarijn@blazhoffski.nl 2015-04-01    49563        307.50
# 16                  pr@bijlmerparktheater.nl 2015-04-01    49598       1185.00
# 17                    cleogoossens@gmail.com 2015-04-01    49606         66.50
# 18                          k.kievit@vabi.nl 2015-04-01    49607        442.00
# 19                    maartenve1@hotmail.com 2015-04-01    49609        179.00
# 20                           edwin@edit4u.nl 2015-04-01    49610        134.00
# 21               administration@radialsg.com 2015-04-01    49614        295.00
# 22                       ferry@dpscompany.nl 2015-04-01    49624        300.00
# 23                     ewillems@insulcon.com 2015-04-01    49625        156.00
# 24                        s.portente@bpaz.nl 2015-04-01    49627        545.00
# 25                racheldijkstra@hotmail.com 2015-04-01    49628        149.00
# 26                  info@kilometerfresser.eu 2015-04-01    49631        161.00
# 27                s.nuijts@maritiemmuseum.nl 2015-04-01    49632          0.00
# 28                         antonbaier@web.de 2015-04-01    49634        285.00
# 29                     kimlokers@hotmail.com 2015-04-01    49635        249.80
# ...                                      ...        ...      ...           ...
# 1136                  info@silviaagterhof.nl 2015-04-30    51276          0.00
# 1137                  info@silviaagterhof.nl 2015-04-30    51276          0.00
# 1138                  nina.pfeiffer@doka.com 2015-04-30    51278        267.89
# 1139               keller@mk-fachberatung.de 2015-04-30    51285          0.00
# 1140             anita@socialmediamonteur.nl 2015-04-30    51288        152.50
# 1141                  info@unicacoatings.com 2015-04-30    51292        185.00
# 1142            gisele.russano@blacklane.com 2015-04-30    51293        567.00
# 1143            gisele.russano@blacklane.com 2015-04-30    51293        567.00
# 1144               julia.koch@harveynash.com 2015-04-30    51295        579.00
# 1145                 a.w.joldersma@gmail.com 2015-04-30    51296          0.00
# 1146                   andreaslmmr@gmail.com 2015-04-30    51301        239.60
# 1147                      post@alice-ruff.de 2015-04-30    51304          0.00
# 1148                 mc.schinopgeul@ezorg.nl 2015-04-30    51308        260.00
# 1149                    eefjedek@hotmail.com 2015-04-30    51309        203.28
# 1150                         info@koifarm.be 2015-04-30    51310        200.00
# 1151                robhamberg@securityxl.nl 2015-04-30    51312        175.20
# 1152                 Laurens@fashionclash.nl 2015-04-30    51313        440.00
# 1153                       beck@wortland.com 2015-04-30    51319        174.00
# 1154                     info@oranjebruin.nl 2015-04-30    51321        245.00
# 1155                 voorzitter@intermate.nl 2015-04-30    51328          0.00
# 1156                    charlotte@maxilia.nl 2015-04-30    51329        161.00
# 1157                 voorzitter@intermate.nl 2015-04-30    51331        305.80
# 1158                    charlotte@maxilia.nl 2015-04-30    51332        117.00
# 1159                         marcel@manzs.nl 2015-04-30    51333        430.00
# 1160               bartvanrooij7@hotmail.com 2015-04-30    51334        346.83
# 1161               bartvanrooij7@hotmail.com 2015-04-30    51334        346.83
# 1162               bartvanrooij7@hotmail.com 2015-04-30    51334        346.83
# 1163               bartvanrooij7@hotmail.com 2015-04-30    51334        346.83
# 1164                            info@prct.nl 2015-04-30    51336        183.00
# 1165                    1234snij@hotmail.com 2015-04-30    51337        480.00
#
# [1166 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 4 columns):
# email           1166 non-null object
# Orderdate       1166 non-null datetime64[ns]
# OrderID         1166 non-null int64
# TurnoverLead    1166 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 36.5+ KB

# %%
# lege rijen 'NaT' eruit gefilterd 

df = df.dropna(axis=0, how = 'any', inplace=False)
df = df[~df['email'].str.contains('@')==False]
df.head()
# Out:
#                             email  Orderdate  OrderID  TurnoverLead
# 0               jw@a-m-service.de 2015-04-01    44409         494.0
# 1      mieke.sanders@verscombi.nl 2015-04-01    48003         460.0
# 2      mieke.sanders@verscombi.nl 2015-04-01    48003         460.0
# 3  beate.hardtke@dertouristik.com 2015-04-01    48957        2385.0
# 4       follower4christ@gmail.com 2015-04-01    49063         970.0

# %%
df['Orderdate']=pd.to_datetime(df['Orderdate'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1166 entries, 0 to 1165
# Data columns (total 4 columns):
# email           1166 non-null object
# Orderdate       1166 non-null datetime64[ns]
# OrderID         1166 non-null int64
# TurnoverLead    1166 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 45.5+ KB

# %%
df.describe()
# Out:
#             OrderID  TurnoverLead
# count   1166.000000   1166.000000
# mean   50169.558319    558.120583
# std     1081.732008   1082.852207
# min    30777.000000      0.000000
# 25%    49825.500000    162.000000
# 50%    50271.000000    277.750000
# 75%    50774.750000    550.000000
# max    51337.000000  15763.600000

# %%
assert ptypes.is_datetime64_any_dtype(df['Orderdate'])
assert all(df[df['email'].str.contains('@')])

# %% [markdown]
# # Data grouperen per klant

# %%
# group by customer ID
# hoeveel orders zijn er gedaan per customer
# totale uitgaven per customer 

df_clv = df.groupby('email').agg({
                                                        'Orderdate': lambda date: (date.max() - date.min()).days,
                                                        'OrderID': lambda num: len(num), 
                                                        'TurnoverLead': lambda price: price.sum()
                                                    }) 
df_clv.head()
# Out:
#                          Orderdate  OrderID  TurnoverLead
# email
# 1234snij@hotmail.com             0        1         480.0
# ABeks@brabant.nl                 0        1         804.5
# Andre@tk-timmerwerk.nl           0        2        1580.0
# Anneheirman@gmail.com            0        1         380.5
# Annerieke@start2move.nl          0        1        1605.0

# %%
# rename kolommen 

df_clv.columns = ['days_customer', 'total_transactions', 'total_spent']
df_clv.head()
# Out:
#                          days_customer  total_transactions  total_spent
# email
# 1234snij@hotmail.com                 0                   1        480.0
# ABeks@brabant.nl                     0                   1        804.5
# Andre@tk-timmerwerk.nl               0                   2       1580.0
# Anneheirman@gmail.com                0                   1        380.5
# Annerieke@start2move.nl              0                   1       1605.0

# %%
df_clv.describe()
# Out:
#        days_customer  total_transactions   total_spent
# count     927.000000          927.000000    927.000000
# mean        0.235167            1.257821    702.015750
# std         1.785692            0.734362   2137.260749
# min         0.000000            1.000000      0.000000
# 25%         0.000000            1.000000    169.500000
# 50%         0.000000            1.000000    285.000000
# 75%         0.000000            1.000000    565.000000
# max        27.000000           10.000000  33990.000000

# %% [markdown]
# # Berekenen van de totale CLV

# %%
# gemiddelde order waarde 

avg_order_value = sum(df_clv['total_spent']) / sum(df_clv['total_transactions'])
print(avg_order_value)
# Out:
# 558.1205831903948

# %%
# hoe vaak koopt iemand gemiddeld iets

purchase_frequency = sum(df_clv['total_transactions']) / df_clv.shape[0]
print(purchase_frequency)
# Out:
# 1.2578209277238404

# %%
# hoe vaak komt iemand terug

repeat_rate = df_clv[df_clv.total_transactions > 1].shape[0] / df_clv.shape[0] 
print(repeat_rate)
# Out:
# 0.16936353829557713

# %%
# churnrate: hoeveel % doet na 1 aankoop geen bestelling meer

churn_rate = 1 - repeat_rate
print(churn_rate)
# Out:
# 0.8306364617044228

# %%
# gemiddelde marge  

#profit = sum(df['TurnoverLead']) - sum(df['BuyinLead'])
#margin = profit / sum(df['TurnoverLead'])
    
#print(margin)

# %%
# totale clv & clv marge 
# in het blok hierboven is de marge berekend ('margin'), maar je kan ook een getal noteren ipv 'margin'

total_clv = (avg_order_value * purchase_frequency) / churn_rate 
#total_clv_margin = total_clv * margin

print(total_clv) # het eerste getal is de totale clv
#print(total_clv_margin) # het tweede getal is de clv waarbij rekening is gehouden met de berekende marge
# Out:
# 845.1540259740264

# %%
# Bovenstaande cijfers in kolom neerzetten zodat de data in datastudio kan worden gebruikt
set_total_clv = avg_order_value, purchase_frequency, churn_rate, total_clv, total_clv_margin 
df_total_clv = pd.DataFrame(set_total_clv, columns= ['Waarde'], index = ['Gemiddelde orderwaarde' , 'Frequentie aankoop', 'Churn rate' , 'CLV', 'CLV marge'])
df_clv_values=df_total_clv.T.groupby(level=0).agg(lambda x : x.values.tolist()).stack().apply(pd.Series).unstack().sort_index(level=1,axis=1)
df_clv_values.columns=df_clv_values.columns.droplevel(level=0)
df_clv_values.head()
# Out:
#                 CLV   CLV marge  Churn rate  Frequentie aankoop  \
# Waarde  2151.439226  854.248053    0.696111            1.801011
#
#         Gemiddelde orderwaarde
# Waarde              831.555278

# %%
df_clv_values.to_excel('CLV_waardes.xlsx')

# %% [markdown]
#    # Transacties en churn rate per maand uiteenzetten

# %%
# transacties per klant per maand uiteenzetten
df_monthly = df.set_index('Orderdate')
df_monthly = df_monthly.pivot_table(
    index=['email'],
    columns=pd.Grouper(freq='M'),
    values='OrderID', 
    aggfunc='count',
    fill_value=0
)

# Format column headers to human readable format
df_monthly.columns = [x.strftime('%b-%Y') for x in df_monthly.columns]

df_monthly.head()
# Out:
#                           Apr-2014  Jul-2014  Sep-2014  Oct-2014  Nov-2014  \
# email
# 00kippie@planet.nl               0         0         0         0         0
# 03vichy@gmail.com                0         0         0         0         0
# 06alexisbrunet@gmail.com         0         0         0         0         0
# 070paulus070@gmail.com           0         0         0         0         0
# 0910975@hr.nl                    0         0         0         0         0
#
#                           Dec-2014  Jan-2015  Feb-2015  Mar-2015  Apr-2015  \
# email
# 00kippie@planet.nl               0         0         1         0         0
# 03vichy@gmail.com                0         0         0         0         0
# 06alexisbrunet@gmail.com         0         0         0         0         0
# 070paulus070@gmail.com           0         0         0         0         0
# 0910975@hr.nl                    0         0         0         0         0
#
#                           ...  Dec-2018  Jan-2019  Feb-2019  Mar-2019  \
# email                     ...
# 00kippie@planet.nl        ...         0         0         0         0
# 03vichy@gmail.com         ...         0         0         0         0
# 06alexisbrunet@gmail.com  ...         0         0         0         0
# 070paulus070@gmail.com    ...         0         0         0         0
# 0910975@hr.nl             ...         0         0         0         0
#
#                           Apr-2019  May-2019  Jun-2019  Jul-2019  Aug-2019  \
# email
# 00kippie@planet.nl               0         0         0         0         0
# 03vichy@gmail.com                0         0         0         0         0
# 06alexisbrunet@gmail.com         0         0         0         0         0
# 070paulus070@gmail.com           0         0         0         1         0
# 0910975@hr.nl                    0         0         0         0         0
#
#                           Sep-2019
# email
# 00kippie@planet.nl               0
# 03vichy@gmail.com                0
# 06alexisbrunet@gmail.com         0
# 070paulus070@gmail.com           0
# 0910975@hr.nl                    0
#
# [5 rows x 63 columns]

# %%
repeat_rate = df_monthly[df_monthly > 1].count() / len(df_monthly)
df_churn = repeat_rate.to_frame(name='repeat_rate')

# %%
df_churn['churn_rate'] = 1 - df_churn['repeat_rate']
df_churn.head()
# Out:
#           repeat_rate  churn_rate
# Apr-2014     0.000000    1.000000
# Jul-2014     0.000014    0.999986
# Sep-2014     0.000000    1.000000
# Oct-2014     0.000014    0.999986
# Nov-2014     0.000027    0.999973

# %% [markdown]
# # CLV per klant uitrekenen

# %%
# clv per customer

df_clv['customer_order_value'] = df_clv['total_spent'] / df_clv['total_transactions']
df_clv['customer_clv'] = (df_clv['customer_order_value'] * purchase_frequency) / churn_rate
df_clv['customer_clv_margin'] = df_clv['customer_clv'] * margin

df_clv.head()
# Out:
#                           days_customer  total_transactions  total_spent  \
# email
# 00kippie@planet.nl                    0                   1        125.0
# 03vichy@gmail.com                     0                   1        259.0
# 06alexisbrunet@gmail.com              0                   1        180.0
# 070paulus070@gmail.com                0                   1         33.5
# 0910975@hr.nl                         0                   1        430.0
#
#                           customer_order_value  customer_clv  \
# email
# 00kippie@planet.nl                       125.0    323.405924
# 03vichy@gmail.com                        259.0    670.097075
# 06alexisbrunet@gmail.com                 180.0    465.704531
# 070paulus070@gmail.com                    33.5     86.672788
# 0910975@hr.nl                            430.0   1112.516380
#
#                           customer_clv_margin
# email
# 00kippie@planet.nl                 128.411195
# 03vichy@gmail.com                  266.067995
# 06alexisbrunet@gmail.com           184.912120
# 070paulus070@gmail.com              34.414200
# 0910975@hr.nl                      441.734510

# %%
df_clv.describe()
# Out:
#        days_customer  total_transactions   total_spent  customer_order_value  \
# count   72793.000000        72793.000000  7.279300e+04          72793.000000
# mean       74.874370            1.801011  1.497640e+03            547.447264
# std       223.708098            2.755637  1.365772e+04           1150.759735
# min         0.000000            1.000000 -7.840000e+02           -392.000000
# 25%         0.000000            1.000000  1.751600e+02            160.000000
# 50%         0.000000            1.000000  3.500000e+02            287.500000
# 75%         0.000000            2.000000  8.909000e+02            567.500000
# max      1723.000000          184.000000  2.105784e+06         110830.736842
#
#         customer_clv  customer_clv_margin
# count   72793.000000         72793.000000
# mean     1416.381509           562.386858
# std      2977.300127          1182.163459
# min     -1014.200979          -402.697507
# 25%       413.959583           164.366329
# 50%       743.833626           295.345748
# 75%      1468.262897           582.986824
# max    286746.535182        113855.258617

# %%
df_clv.to_excel('CLV_per_klant.xlsx')

# %%
# Uiteenzetting uitgaves klanten per maand
df['month_yr'] = df['Orderdate'].apply(lambda x: x.strftime('%b-%Y'))
df.head()
# Out:
#    OrderID  Orderdate                              email  TurnoverLead  \
# 0    27654 2014-04-22  janneke.van.wingerden@hotmail.com         840.0
# 1    30777 2015-04-09             marloessanders@izit.nl         300.0
# 2    32291 2014-07-30              info@ferox-design.com         235.0
# 3    32291 2014-07-30              info@ferox-design.com         235.0
# 4    33824 2016-05-27              johan@thermservice.be           0.0
#
#    BuyinLead  month_yr
# 0        0.0  Apr-2014
# 1        0.0  Apr-2015
# 2        0.0  Jul-2014
# 3        0.0  Jul-2014
# 4        0.0  May-2016

# %%
#totale transacties / opbrengst per maand

df_transacties = df.groupby('month_yr').aggregate({
                                                        'OrderID': lambda num: len(num), 
                                                        'TurnoverLead': lambda price: price.sum(),
                                                        'email': pd.Series.nunique
                                                    }) 
df_transacties.head()
# Out:
#           OrderID  TurnoverLead  email
# month_yr
# Apr-2014        1        840.00      1
# Apr-2015     1167     650938.60    928
# Apr-2016     1543    1152839.06   1201
# Apr-2017     1483    1147994.84   1132
# Apr-2018     2755    2413270.00   2054

# %%
df_transacties.columns = ['total_transactions', 'total_spent', 'total_unique_customers']
df_transacties.head()
# Out:
#           total_transactions  total_spent  total_unique_customers
# month_yr
# Apr-2014                   1       840.00                       1
# Apr-2015                1167    650938.60                     928
# Apr-2016                1543   1152839.06                    1201
# Apr-2017                1483   1147994.84                    1132
# Apr-2018                2755   2413270.00                    2054

# %%
df_transacties.describe()
# Out:
#        total_transactions   total_spent  total_unique_customers
# count           63.000000  6.300000e+01               63.000000
# mean          2080.968254  1.730440e+06             1562.476190
# std           1178.428053  1.060242e+06              839.415942
# min              1.000000  2.190000e+02                1.000000
# 25%           1343.500000  9.513474e+05             1052.500000
# 50%           1844.000000  1.534700e+06             1423.000000
# 75%           2861.500000  2.594284e+06             2104.500000
# max           4962.000000  3.937462e+06             3679.000000

# %%
df_transacties.to_excel('Overzicht_per_maand.xlsx')

# %% [markdown]
# # CLV per maand berekenen

# %%
# CLV per maand berekenen
df_transacties['purchase_frequency_month'] = df_transacties['total_transactions'] / df_transacties['total_unique_customers']
df_transacties['avg_order_value_month'] = df_transacties['total_spent'] / df_transacties['total_transactions'] 
df_transacties['CLV'] = (df_transacties['avg_order_value_month'] * df_transacties['purchase_frequency_month']) / df_churn['churn_rate']
df_transacties['CLV_margin'] = df_transacties['CLV']*margin
df_transacties.head()
# Out:
#           total_transactions  total_spent  total_unique_customers  \
# month_yr
# Apr-2014                   1       840.00                       1
# Apr-2015                1167    650938.60                     928
# Apr-2016                1543   1152839.06                    1201
# Apr-2017                1483   1147994.84                    1132
# Apr-2018                2755   2413270.00                    2054
#
#           purchase_frequency_month  avg_order_value_month          CLV  \
# month_yr
# Apr-2014                  1.000000             840.000000   840.000000
# Apr-2015                  1.257543             557.788003   702.958599
# Apr-2016                  1.284763             747.141322   962.862239
# Apr-2017                  1.310071             774.103061  1017.133904
# Apr-2018                  1.341285             875.960073  1181.469503
#
#           CLV_margin
# month_yr
# Apr-2014  333.529461
# Apr-2015  279.115955
# Apr-2016  382.313004
# Apr-2017  403.862051
# Apr-2018  469.112960

# %% [markdown]
# # Statistieken CLV per klant

# %%
# statistieken van clv per customer 

import statistics

df_clv_list = df_clv['customer_clv'].values

x1 = statistics.mean(df_clv_list) # eerste getal is gemiddelde
x2 = statistics.median(df_clv_list) # tweede getal is mediaan
x3 = statistics.mode(df_clv_list) # derde getal is de modus 
x4 = statistics.stdev(df_clv_list) # vierde getal is de standaarddeviatie 

print(x1) 
print(x2) 
print(x3) 
print(x4)
# Out:
# 1416.381508584541
# 743.8336260656772
# 0.0
# 2977.3001273082336

# %%
# box plot: visuele weergaven van de verdeling van de clv 
# zichtbaar = minimum, maximum, mediaan en kwartielafstanden 

import matplotlib.pyplot as plt 
df_clv.plot(y = 'customer_clv', kind = 'box') 
plt.show()

# %%
# histogram plot: visuele weergaven van frequentie verdeling van de clv 
# hoe vaak komt een clv waarde voor 

import matplotlib.pyplot as plt 
df_clv.plot(y = 'customer_clv', kind = 'hist') 
plt.show()
